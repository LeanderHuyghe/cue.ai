# %%
pip install streamlit openai sentence-transformers numpy
# Out:
# Looking in indexes: https://****@artifacts.uberinternal.com/artifactory/api/pypi/pypi/simple/
# WARNING: 401 Error, Credentials not correct for https://artifacts.uberinternal.com/artifactory/api/pypi/pypi/simple/streamlit/
# ERROR: Could not find a version that satisfies the requirement streamlit (from versions: none)
# ERROR: No matching distribution found for streamlit
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install streamlit
# Out:
# Looking in indexes: https://****@artifacts.uberinternal.com/artifactory/api/pypi/pypi/simple/
# WARNING: 401 Error, Credentials not correct for https://artifacts.uberinternal.com/artifactory/api/pypi/pypi/simple/streamlit/
# ERROR: Could not find a version that satisfies the requirement streamlit (from versions: none)
# ERROR: No matching distribution found for streamlit
# Note: you may need to restart the kernel to use updated packages.

# %%
import os

# %%
from openai import OpenAI
OPEN_AI_KEY = '' # Add key here
client = OpenAI(api_key=os.environ[OPEN_AI_KEY])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 3
#       1 from openai import OpenAI
#       2 OPEN_AI_KEY = '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' # Add key here
# ----> 3 client = OpenAI(api_key=os.environ[OPEN_AI_KEY])
#
# File <frozen os>:679, in __getitem__(self, key)
#
# KeyError: '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'
